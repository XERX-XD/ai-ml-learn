# %%
import pandas as pd

# %%
#read json data

student_data = pd.read_json("../datasets/students_data.json")
#print(student_data)

# %%
#display first 5 row
print(student_data.head(5))
# Out:
#    id           name  age  gender       phone                     email  \
# 0   1  Sabina Pandey   19    Male  9866879003  sabina.pandey1@gmail.com
# 1   2   Sujan Poudel   28    Male  9870676580   sujan.poudel2@gmail.com
# 2   3   Nabin Pandey   26    Male  9834006426   nabin.pandey3@gmail.com
# 3   4   Roshan Regmi   27  Female  9811229824   roshan.regmi4@gmail.com
# 4   5   Anisha Regmi   25    Male  9824458163   anisha.regmi5@gmail.com
#
#     location   district province                        courses_enrolled  \
# 0     Dharan    Sunsari    Koshi                           [NodeJS, C++]
# 1  Nepalgunj      Banke  Lumbini                               [Flutter]
# 2  Kathmandu  Kathmandu  Bagmati  [Django, Deep Learning, Python, React]
# 3     Dharan    Sunsari    Koshi         [Figma, Python, Flutter, Excel]
# 4    Chitwan    Chitwan  Bagmati                          [Data Science]
#
#    fees_paid  fees_due  attendance  marks         batch   join_date  passed  \
# ...

# %%
#display last 3 row
print(student_data.tail(3))
# Out:
#       id           name  age  gender       phone                       email  \
# 497  498  Sabina Khadka   25    Male  9820772678  sabina.khadka498@gmail.com
# 498  499  Rohan Acharya   30  Female  9833337211  rohan.acharya499@gmail.com
# 499  500       Sujan KC   23  Female  9840665873       sujan.kc500@gmail.com
#
#       location  district province                           courses_enrolled  \
# 497   Janakpur  Dhanusha  Madhesh  [C++, Digital Marketing, Excel, Power BI]
# 498    Chitwan   Chitwan  Bagmati                   [C++, Digital Marketing]
# 499  Nepalgunj     Banke  Lumbini                             [Figma, AI/ML]
#
#      fees_paid  fees_due  attendance  marks    batch   join_date  passed  \
# 497      16298      2316          81     85  Evening  2026-07-15    True
# 498      37942      1242          73     65  Evening  2026-01-09    True
# 499      27145       917          65     98  Morning  2026-12-19    True
#
#      scholarship
# 497        False
# ...

# %%
#find the shape of dataset ,,, row , column
print(student_data.shape) #row colurm
# Out:
# (500, 18)

# %%
#display column names
print(student_data.columns)
# Out:
# Index(['id', 'name', 'age', 'gender', 'phone', 'email', 'location', 'district',
#        'province', 'courses_enrolled', 'fees_paid', 'fees_due', 'attendance',
#        'marks', 'batch', 'join_date', 'passed', 'scholarship'],
#       dtype='str')

# %%
#display data types
print(student_data.dtypes)
# Out:
# id                   int64
# name                   str
# age                  int64
# gender                 str
# phone                int64
# email                  str
# location               str
# district               str
# province               str
# courses_enrolled    object
# fees_paid            int64
# fees_due             int64
# attendance           int64
# marks                int64
# batch                  str
# join_date              str
# passed                bool
# scholarship           bool
# dtype: object

# %%
#show complete information using info()
print(student_data.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                500 non-null    int64
#  1   name              500 non-null    str
#  2   age               500 non-null    int64
#  3   gender            500 non-null    str
#  4   phone             500 non-null    int64
#  5   email             500 non-null    str
#  6   location          500 non-null    str
#  7   district          500 non-null    str
#  8   province          500 non-null    str
#  9   courses_enrolled  500 non-null    object
#  10  fees_paid         500 non-null    int64
#  11  fees_due          500 non-null    int64
#  12  attendance        500 non-null    int64
#  13  marks             500 non-null    int64
#  14  batch             500 non-null    str
#  15  join_date         500 non-null    str
#  16  passed            500 non-null    bool
# ...

# %%
#display statistical summary using describe
print(student_data.describe())
# Out:
#                id         age         phone     fees_paid     fees_due  \
# count  500.000000  500.000000  5.000000e+02    500.000000   500.000000
# mean   250.500000   23.746000  9.850151e+09  33232.086000  5137.020000
# std    144.481833    3.932482  2.944077e+07  10109.900089  2947.700174
# min      1.000000   17.000000  9.800039e+09  15148.000000    29.000000
# 25%    125.750000   20.000000  9.823999e+09  23946.000000  2458.750000
# 50%    250.500000   24.000000  9.851883e+09  34022.500000  5427.500000
# 75%    375.250000   27.000000  9.875147e+09  41986.500000  7572.250000
# max    500.000000   30.000000  9.899911e+09  49911.000000  9986.000000
#
#        attendance       marks
# count  500.000000  500.000000
# mean    80.402000   71.670000
# std     12.436951   16.250454
# min     60.000000   45.000000
# 25%     69.000000   58.000000
# 50%     81.000000   70.000000
# 75%     92.000000   86.000000
# max    100.000000   99.000000

# %%
#display only name column
print(student_data["name"])
# Out:
# 0      Sabina Pandey
# 1       Sujan Poudel
# 2       Nabin Pandey
# 3       Roshan Regmi
# 4       Anisha Regmi
#            ...
# 495       Asmita Rai
# 496     Ramesh Joshi
# 497    Sabina Khadka
# 498    Rohan Acharya
# 499         Sujan KC
# Name: name, Length: 500, dtype: str

# %%
#display name and age
print(student_data[["name","age"]])
# Out:
#               name  age
# 0    Sabina Pandey   19
# 1     Sujan Poudel   28
# 2     Nabin Pandey   26
# 3     Roshan Regmi   27
# 4     Anisha Regmi   25
# ..             ...  ...
# 495     Asmita Rai   27
# 496   Ramesh Joshi   28
# 497  Sabina Khadka   25
# 498  Rohan Acharya   30
# 499       Sujan KC   23
#
# [500 rows x 2 columns]

# %%
#display first student
print(student_data.head(1))
# Out:
#    id           name  age gender       phone                     email  \
# 0   1  Sabina Pandey   19   Male  9866879003  sabina.pandey1@gmail.com
#
#   location district province courses_enrolled  fees_paid  fees_due  \
# 0   Dharan  Sunsari    Koshi    [NodeJS, C++]      17394      1532
#
#    attendance  marks         batch   join_date  passed  scholarship
# 0          60     84  AI Udaan Day  2026-07-26    True        False

# %%
#display last student
print(student_data.tail(1))
# Out:
#       id      name  age  gender       phone                  email   location  \
# 499  500  Sujan KC   23  Female  9840665873  sujan.kc500@gmail.com  Nepalgunj
#
#     district province courses_enrolled  fees_paid  fees_due  attendance  \
# 499    Banke  Lumbini   [Figma, AI/ML]      27145       917          65
#
#      marks    batch   join_date  passed  scholarship
# 499     98  Morning  2026-12-19    True        False

# %%
#display student data if id = 5
print(student_data[student_data["id"]==5])
# Out:
#    id          name  age gender       phone                    email location  \
# 4   5  Anisha Regmi   25   Male  9824458163  anisha.regmi5@gmail.com  Chitwan
#
#   district province courses_enrolled  fees_paid  fees_due  attendance  marks  \
# 4  Chitwan  Bagmati   [Data Science]      23403      6333          76     62
#
#      batch   join_date  passed  scholarship
# 4  Evening  2026-12-20    True        False

# %%
#display all student info if location = kathmandu
print(student_data[student_data["location"]=="Kathmandu"])
# Out:
#       id              name  age  gender       phone  \
# 2      3      Nabin Pandey   26    Male  9834006426
# 14    15      Ramesh Dahal   17  Female  9819481915
# 15    16    Suman Adhikari   26  Female  9874774221
# 49    50      Suman Gautam   24  Female  9818038621
# 51    52        Sita Joshi   26    Male  9809412290
# 58    59      Alina Pandey   29  Female  9877806260
# 60    61       Gita Pandey   22    Male  9832380586
# 80    81      Asmita Magar   28    Male  9804393568
# 82    83  Prakash Adhikari   24    Male  9887484710
# 84    85      Ritika Dahal   17  Female  9893591663
# 102  103    Suman Shrestha   17  Female  9882237253
# 104  105      Anisha Karki   27  Female  9885151375
# 143  144         Ramesh KC   30    Male  9853758736
# 155  156       Ramesh Lama   25  Female  9804641806
# 156  157    Prakash Pandey   17    Male  9836680686
# 157  158    Alina Adhikari   23    Male  9809190897
# 162  163       Alina Dahal   22  Female  9815602549
# ...

# %%
#display student data if student is older then 21
print(student_data[student_data["age"]>21])
# Out:
#       id           name  age  gender       phone                       email  \
# 1      2   Sujan Poudel   28    Male  9870676580     sujan.poudel2@gmail.com
# 2      3   Nabin Pandey   26    Male  9834006426     nabin.pandey3@gmail.com
# 3      4   Roshan Regmi   27  Female  9811229824     roshan.regmi4@gmail.com
# 4      5   Anisha Regmi   25    Male  9824458163     anisha.regmi5@gmail.com
# 6      7     Gita Magar   22    Male  9820101977       gita.magar7@gmail.com
# ..   ...            ...  ...     ...         ...                         ...
# 495  496     Asmita Rai   27  Female  9836813605     asmita.rai496@gmail.com
# 496  497   Ramesh Joshi   28    Male  9826553259   ramesh.joshi497@gmail.com
# 497  498  Sabina Khadka   25    Male  9820772678  sabina.khadka498@gmail.com
# 498  499  Rohan Acharya   30  Female  9833337211  rohan.acharya499@gmail.com
# 499  500       Sujan KC   23  Female  9840665873       sujan.kc500@gmail.com
#
# ...

# %%
#display female student
print(student_data[student_data["gender"]=="Female"])
# Out:
#       id           name  age  gender       phone                       email  \
# 3      4   Roshan Regmi   27  Female  9811229824     roshan.regmi4@gmail.com
# 5      6   Ramesh Magar   20  Female  9825490998     ramesh.magar6@gmail.com
# 8      9    Alina Joshi   27  Female  9828747392      alina.joshi9@gmail.com
# 11    12   Kiran Poudel   25  Female  9803953697    kiran.poudel12@gmail.com
# 13    14   Roshan Thapa   29  Female  9834257153    roshan.thapa14@gmail.com
# ..   ...            ...  ...     ...         ...                         ...
# 493  494    Mina Sharma   25  Female  9857967801    mina.sharma494@gmail.com
# 494  495  Asmita Gautam   21  Female  9803716146  asmita.gautam495@gmail.com
# 495  496     Asmita Rai   27  Female  9836813605     asmita.rai496@gmail.com
# 498  499  Rohan Acharya   30  Female  9833337211  rohan.acharya499@gmail.com
# 499  500       Sujan KC   23  Female  9840665873       sujan.kc500@gmail.com
#
#       location   district province  \
# ...

# %%
#diplay the students data whose attendance is greater then 90
print(student_data[student_data["attendance"]>=90])
# Out:
#       id           name  age  gender       phone                       email  \
# 2      3   Nabin Pandey   26    Male  9834006426     nabin.pandey3@gmail.com
# 3      4   Roshan Regmi   27  Female  9811229824     roshan.regmi4@gmail.com
# 6      7     Gita Magar   22    Male  9820101977       gita.magar7@gmail.com
# 8      9    Alina Joshi   27  Female  9828747392      alina.joshi9@gmail.com
# 9     10    Sujan Dahal   18    Male  9883749719     sujan.dahal10@gmail.com
# ..   ...            ...  ...     ...         ...                         ...
# 479  480   Pooja Poudel   23    Male  9842710675   pooja.poudel480@gmail.com
# 482  483  Nisha Acharya   24    Male  9881680664  nisha.acharya483@gmail.com
# 488  489     Prakash KC   24  Female  9871798830     prakash.kc489@gmail.com
# 490  491       Pooja KC   28  Female  9867136985       pooja.kc491@gmail.com
# 496  497   Ramesh Joshi   28    Male  9826553259   ramesh.joshi497@gmail.com
#
# ...

# %%
#display the students whose marks are above 85
print(student_data[student_data["marks"]>=85])
# Out:
#       id            name  age  gender       phone                       email  \
# 5      6    Ramesh Magar   20  Female  9825490998     ramesh.magar6@gmail.com
# 7      8   Asmita Pandey   21    Male  9812467748    asmita.pandey8@gmail.com
# 11    12    Kiran Poudel   25  Female  9803953697    kiran.poudel12@gmail.com
# 13    14    Roshan Thapa   29  Female  9834257153    roshan.thapa14@gmail.com
# 15    16  Suman Adhikari   26  Female  9874774221  suman.adhikari16@gmail.com
# ..   ...             ...  ...     ...         ...                         ...
# 487  488    Sujan Poudel   30  Female  9885368000   sujan.poudel488@gmail.com
# 491  492   Ritika Poudel   28  Female  9827170264  ritika.poudel492@gmail.com
# 496  497    Ramesh Joshi   28    Male  9826553259   ramesh.joshi497@gmail.com
# 497  498   Sabina Khadka   25    Male  9820772678  sabina.khadka498@gmail.com
# 499  500        Sujan KC   23  Female  9840665873       sujan.kc500@gmail.com
#
# ...

# %%
#display students who enrolled in python
print(student_data[student_data["courses_enrolled"].apply(lambda x: "Python" in x)])
# Out:
#       id             name  age  gender       phone  \
# 2      3     Nabin Pandey   26    Male  9834006426
# 3      4     Roshan Regmi   27  Female  9811229824
# 17    18     Sabina Dahal   19  Female  9888478039
# 19    20  Sabina Shrestha   20  Female  9851899869
# 22    23  Nabin Bhattarai   24    Male  9833072767
# ..   ...              ...  ...     ...         ...
# 468  469        Roshan KC   24  Female  9873162845
# 470  471     Asmita Joshi   26    Male  9806889815
# 473  474    Ritika Pandey   27    Male  9840557150
# 484  485   Alina Bhandari   26    Male  9801096657
# 490  491         Pooja KC   28  Female  9867136985
#
#                            email   location   district province  \
# 2        nabin.pandey3@gmail.com  Kathmandu  Kathmandu  Bagmati
# 3        roshan.regmi4@gmail.com     Dharan    Sunsari    Koshi
# 17      sabina.dahal18@gmail.com    Itahari    Sunsari    Koshi
# 19   sabina.shrestha20@gmail.com  Nepalgunj      Banke  Lumbini
# ...

# %% [markdown]
# completed all 20 assignment
