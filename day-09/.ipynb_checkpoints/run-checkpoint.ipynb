# %%
import pandas as pd

# %%
student_json = pd.read_json("../datasets/students_data.json")
#print(student_json)

# %%
#nd = netflix dataset
nd = pd.read_csv("../datasets/netflix_dataset.csv")
#print(nd)
#head(num) to get the head of first num from file

#print(nd.head(1))
#print(nd.tail(2)) #last 2 rows return 

print(nd.sample(3)) #return randomly 3 from dataset
# Out:
#      show_id     type                    title  \
# 5332   s5333    Movie                  Demonic
# 2737   s2738    Movie  Mighty Raju Rio Calling
# 2992   s2993  TV Show    Sons of the Caliphate
#
#                                                director  \
# 5332                                         Will Canon
# 2737  Rajiv Chilaka, Anirban Majumder, Alka Amarkant...
# 2992                                                NaN
#
#                                                    cast        country  \
# 5332  Maria Bello, Frank Grillo, Cody Horn, Dustin M...  United States
# 2737                                                NaN          India
# 2992  Yakubu Mohammed, Paul Sambo, Mofe Duncan, Nita...        Nigeria
#
#             date_added  release_year rating   duration  \
# 5332   August 10, 2017          2015      R     83 min
# 2737     April 1, 2020          2014  TV-Y7     97 min
# 2992  January 24, 2020          2017  TV-14  2 Seasons
#
# ...

# %%
print(nd.shape) #its return tupple value row,coloum
print(nd.columns) #its return the dataset column 
print(nd.dtypes) # its return the type of column data type like str or int
# Out:
# (8807, 12)
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='str')
# show_id           str
# type              str
# title             str
# director          str
# cast              str
# country           str
# date_added        str
# release_year    int64
# rating            str
# duration          str
# listed_in         str
# description       str
# dtype: object

# %%
print(nd.info()) #shape,column,dtype all in one master method

# non-null = xaina
# for example director 
# total row 8807
# and non -null 6173

# so the 8807-6173 2634 so there is 2634 data missing
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   str
#  1   type          8807 non-null   str
#  2   title         8807 non-null   str
#  3   director      6173 non-null   str
#  4   cast          7982 non-null   str
#  5   country       7976 non-null   str
#  6   date_added    8797 non-null   str
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   str
#  9   duration      8804 non-null   str
#  10  listed_in     8807 non-null   str
#  11  description   8807 non-null   str
# dtypes: int64(1), str(11)
# memory usage: 825.8 KB
# None

# %%
print(nd.describe()) #its show all numerical columns only
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
# Out:
# count    8807.000000
# mean     2014.180198
# std         8.819312
# min      1925.000000
# 25%      2013.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2021.000000
# Name: release_year, dtype: float64

# %%
s = nd["release_year"].sort_values().reset_index(drop=True)

print(len(s))        # 8807
print(s.iloc[2201])  # 2013
print(s.iloc[4403])  # 2017
print(s.iloc[6604])  # 2019 full code
# Out:
# 8807
# 2013
# 2017
# 2019
