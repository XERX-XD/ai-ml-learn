# %%
import pandas as pd

# %%
print("hello world")
# Out:
# hello world

# %%
country =pd.Series(["japan","Nepal","Usa"])

# %%
print(country)
# Out:
# 0    japan
# 1    Nepal
# 2      Usa
# dtype: str

# %%
num =pd.Series([20,30,40],index=["ek","dui","teen"])

# %%
print(num["ek"])
# Out:
# 20

# %%
student_data ={
    "name":["Aryan","Kapil","Dhanraj"],
    "age":[20,19,20],
    "course":["ai_udan","mern_stack","devops"],
}
student_dataframe = pd.DataFrame(student_data,index=[1,2,3])
print(student_dataframe)
# Out:
#       name  age      course
# 1    Aryan   20     ai udan
# 2    Kapil   19  mern stack
# 3  Dhanraj   20      devops

# %%
student_csv=pd.read_csv("../datasets/student_dataset.csv")
print(student_csv)
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# ...

# %%
dummydata= pd.read_excel("../datasets/dummy.xlsx")
print(dummydata)
# Out:
#   Scottish Government Programme for International Student Assessment dataset  \
# 0                                     Data Catalogue
# 1                                           Contents
# 2                                    Dataset Details
# 3                                                NaN
# 4                                        Change Log:
# 5                                      December 2024
#
#                                           Unnamed: 1
# 0                                                NaN
# 1                                        Description
# 2  Guidance on the data, catalogue, and a glossar...
# 3                                                NaN
# 4                                                NaN
# 5                          First release of metadata

# %%
student_json = pd.read_json('../datasets/students_data.json')
print(student_json)
# Out:
#       id           name  age  gender       phone                       email  \
# 0      1  Sabina Pandey   19    Male  9866879003    sabina.pandey1@gmail.com
# 1      2   Sujan Poudel   28    Male  9870676580     sujan.poudel2@gmail.com
# 2      3   Nabin Pandey   26    Male  9834006426     nabin.pandey3@gmail.com
# 3      4   Roshan Regmi   27  Female  9811229824     roshan.regmi4@gmail.com
# 4      5   Anisha Regmi   25    Male  9824458163     anisha.regmi5@gmail.com
# ..   ...            ...  ...     ...         ...                         ...
# 495  496     Asmita Rai   27  Female  9836813605     asmita.rai496@gmail.com
# 496  497   Ramesh Joshi   28    Male  9826553259   ramesh.joshi497@gmail.com
# 497  498  Sabina Khadka   25    Male  9820772678  sabina.khadka498@gmail.com
# 498  499  Rohan Acharya   30  Female  9833337211  rohan.acharya499@gmail.com
# 499  500       Sujan KC   23  Female  9840665873       sujan.kc500@gmail.com
#
# ...
