# %%
import numpy as np

# %%
a = np.array([1,5,6])
print(a)
# Out:
# [1 5 6]

# %%
a2arry = np.array(([1,2,3],[2,3,4]))
print(a2arry)
# Out:
# [[1 2 3]
#  [2 3 4]]

# %%
print(a2arry+5)
# Out:
# [[6 7 8]
#  [7 8 9]]

# %%
i = 0
for x in range(1,10+1):
    i+=x
    print(i)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
